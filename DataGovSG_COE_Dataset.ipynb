# %% [markdown]
# <a href="https://colab.research.google.com/github/kerlyn-ong/coe-prices/blob/main/DataGovSG_COE_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# This Jupyter notebook makes it easy to :
#
# 1. Get the dataset and column metadata programmatically
# 2. Load CSV files automatically into a pandas dataframe so you can do the fun explorations

# %% [markdown]
# # Setup
# 1. Paste the dataset ID you copied into the cell below
# 2. Run All Cells (click `Runtime` -> `Run All`)

# %%
DATASET_ID = "d_69b3380ad7e51aff3a7dcc84eba52b8a" # e.g. "d_69b3380ad7e51aff3a7dcc84eba52b8a"
API_KEY = "PASTE_API_KEY_HERE" #e.g. "v2:a7ae10..."

# %% [markdown]
# ## Dataset and Column Metadata

# %%
import json
import requests

s = requests.Session()
s.headers.update({'referer': 'https://colab.research.google.com'})
if API_KEY and API_KEY != "PASTE_API_KEY_HERE":
    s.headers['x-api-key'] = API_KEY
s.headers.update(s.headers)
base_url = "https://api-production.data.gov.sg"
url = base_url + f"/v2/public/api/datasets/{DATASET_ID}/metadata"
print(url)
response = s.get(url)
data = response.json()['data']
columnMetadata = data.pop('columnMetadata', None)

print("Dataset Metadata:")
print(json.dumps(data, indent=2))

print("\nColumns:\n", list(columnMetadata['map'].values()))
# Out:
# https://api-production.data.gov.sg/v2/public/api/datasets/d_69b3380ad7e51aff3a7dcc84eba52b8a/metadata
# Dataset Metadata:
# {
#   "datasetId": "d_69b3380ad7e51aff3a7dcc84eba52b8a",
#   "createdAt": "2024-07-24T16:58:00+08:00",
#   "name": "COE Bidding Results / Prices",
#   "collectionIds": [],
# ...

# %% [markdown]
# ## Download File

# %%
import time
import pandas as pd

def download_file(DATASET_ID, API_KEY=None):

  headers = {"Content-Type": "application/json"}
  if API_KEY:
      headers["x-api-key"] = API_KEY
  # initiate download
  initiate_download_response = s.get(
      f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/initiate-download",
      headers=headers,
      json={}
  )
  print(initiate_download_response.json()['data']['message'])

  # poll download
  MAX_POLLS = 5
  for i in range(MAX_POLLS):
    poll_download_response = s.get(
        f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/poll-download",
        headers=headers,
        json={}
    )
    print("Poll download response:", poll_download_response.json())
    if "url" in poll_download_response.json()['data']:
      print(poll_download_response.json()['data']['url'])
      DOWNLOAD_URL = poll_download_response.json()['data']['url']
      df = pd.read_csv(DOWNLOAD_URL)

      display(df.head())
      print("\nDataframe loaded!")
      return df
    if i == MAX_POLLS - 1:
      print(f"{i+1}/{MAX_POLLS}: No result found, possible error with dataset, please try again or let us know at https://go.gov.sg/datagov-supportform\n")
    else:
      print(f"{i+1}/{MAX_POLLS}: No result yet, continuing to poll\n")
    time.sleep(3)

df = download_file(DATASET_ID)
# Out:
# Download successfully initiated. Proceed to poll download
# ...

# %% [markdown]
# ## Data Cleansing

# %%
#convert month to datetime and rename month to year_month
df['date'] = pd.to_datetime(df['month'])

# #two new columns, month and year
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

#rearrange columns to display nicely
cols = ['date', 'year', 'month'] + \
       [col for col in df.columns if col not in ['date','year','month']]

df = df[cols]

df.dtypes
display(df.head())
# Out:
#         date  year  month  bidding_no vehicle_class  quota bids_success  \
# 0 2010-01-01  2010      1           1    Category A   1152         1145
# 1 2010-01-01  2010      1           1    Category B    687          679
# 2 2010-01-01  2010      1           1    Category C    173          173
# 3 2010-01-01  2010      1           1    Category D    373          365
# 4 2010-01-01  2010      1           1    Category E    586          567
#
#   bids_received  premium
# 0          1342    18502
# 1           883    19190
# 2           265    19001
# 3           509      889
# 4          1011    19889

# %%
#filter to last 5 years
max_date = df['date'].max()

cutoff = max_date - pd.DateOffset(years=5)
df = df[df['date'] >= cutoff]
display(df)
# Out:
#            date  year  month  bidding_no vehicle_class  quota bids_success  \
# 1290 2021-01-01  2021      1           1    Category A    963          962
# 1291 2021-01-01  2021      1           1    Category B   1023         1021
# 1292 2021-01-01  2021      1           1    Category C    372          352
# 1293 2021-01-01  2021      1           1    Category D    529          498
# 1294 2021-01-01  2021      1           1    Category E    467          463
# ...         ...   ...    ...         ...           ...    ...          ...
# 1895 2026-01-01  2026      1           2    Category A   1301        1,277
# 1896 2026-01-01  2026      1           2    Category B    803          800
# 1897 2026-01-01  2026      1           2    Category C    283          280
# 1898 2026-01-01  2026      1           2    Category D    538          523
# 1899 2026-01-01  2026      1           2    Category E    299          299
#
#      bids_received  premium
# 1290          1280    40609
# ...

# %% [markdown]
# ## Dimension and Fact Tables

# %%
#dim date
df['date'] = pd.to_datetime(df['date'])
df['month_name'] = df['date'].dt.month_name()
dim_date = df[['date','year','month','month_name']].drop_duplicates().sort_values('date')
dim_date['datekey'] = dim_date['date'].dt.strftime('%Y%m%d').astype(int)
dim_date = dim_date[['datekey','date','year','month','month_name']]
display(dim_date)

#dim vehicle
vehicle_description ={
'Category A' : 'Non-fully electric cars <= 1,600cc/97kW; Fully electric cars <= 110kW',
'Category B' : 'Non-fully electric cars with engines >1,600cc 97kW; Fully electric cars > 110kW',
'Category C' : 'Goods vehicle and bus',
'Category D' : 'Motorcycle',
'Category E' : 'Open – all except motorcycle'
}

dim_vehicle = pd.DataFrame(list(vehicle_description.items()), columns=['vehicle_class', 'vehicle_description'])
dim_vehicle['category_id'] = range(1, len(dim_vehicle) +1)
dim_vehicle = dim_vehicle[['category_id', 'vehicle_class', 'vehicle_description']]
display(dim_vehicle)
# Out:
#        datekey       date  year  month month_name
# 1290  20210101 2021-01-01  2021      1    January
# 1300  20210201 2021-02-01  2021      2   February
# 1310  20210301 2021-03-01  2021      3      March
# 1320  20210401 2021-04-01  2021      4      April
# 1330  20210501 2021-05-01  2021      5        May
# ...        ...        ...   ...    ...        ...
# 1850  20250901 2025-09-01  2025      9  September
# 1860  20251001 2025-10-01  2025     10    October
# 1870  20251101 2025-11-01  2025     11   November
# 1880  20251201 2025-12-01  2025     12   December
# 1890  20260101 2026-01-01  2026      1    January
#
# [61 rows x 5 columns]
#    category_id vehicle_class  \
# 0            1    Category A
# 1            2    Category B
# 2            3    Category C
# 3            4    Category D
# 4            5    Category E
#
#                                  vehicle_description
# 0  Non-fully electric cars <= 1,600cc/97kW; Fully...
# ...

# %%
#fact coe prices

fact_coe_1 = df.merge(dim_date[['date','datekey']], on='date')
fact_coe_2 = fact_coe_1.merge(dim_vehicle[['category_id','vehicle_class']], on='vehicle_class')

fact_coe = fact_coe_2[['datekey', 'category_id', 'bidding_no', 'quota', 'bids_success', 'bids_received', 'premium']]
display(fact_coe)
# Out:
#       datekey  category_id  bidding_no  quota bids_success bids_received  \
# 0    20210101            1           1    963          962          1280
# 1    20210101            2           1   1023         1021          1396
# 2    20210101            3           1    372          352           679
# 3    20210101            4           1    529          498           692
# 4    20210101            5           1    467          463           758
# ..        ...          ...         ...    ...          ...           ...
# 605  20260101            1           2   1301        1,277         2,303
# 606  20260101            2           2    803          800         1,207
# 607  20260101            3           2    283          280           434
# 608  20260101            4           2    538          523           609
# 609  20260101            5           2    299          299           426
#
#      premium
# 0      40609
# 1      49001
# 2      35900
# 3       7501
# 4      49489
# ...

# %%
#put all df in 1 xlsx file
#instead of import data in excel, do smth here that can directly export to my sheets

from google.colab import userdata
import os
import shutil # Import shutil for removing directories
from google.colab import drive # Import drive for mounting

# Retrieve your secret safely
github_token = userdata.get('github_token')

# --- Configuration --- #
GITHUB_USERNAME = "kerlyn-ong" # Your GitHub username
GITHUB_REPO_NAME = "coe-prices" # Your repository name
GITHUB_EMAIL = userdata.get('github_email') # Your GitHub email
GITHUB_NAME = "kerlynong" # Your GitHub name
GOOGLE_DRIVE_FOLDER_NAME = "Projects"
# --- End Configuration --- #

REPO_PATH = f"/content/{GITHUB_REPO_NAME}"
DATA_PATH = f"{REPO_PATH}/data"

# Ensure we are in the /content directory
# %cd /content/

# Check if the repository already exists locally
if os.path.exists(REPO_PATH) and os.path.exists(os.path.join(REPO_PATH, '.git')):
    print(f"Repository '{GITHUB_REPO_NAME}' already exists. Pulling latest changes...")
    # %cd {REPO_PATH}
    # !git pull https://{github_token}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git
    # %cd /content/
else:
    # If it exists but is not a git repo, clean it up for a fresh clone
    if os.path.exists(REPO_PATH):
        print(f"Found existing non-git directory at {REPO_PATH}. Removing for fresh clone.")
        shutil.rmtree(REPO_PATH)

    # Clone the repository
    print(f"Attempting to clone https://github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git")
    clone_result = !git clone https://{github_token}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git 2>&1

    # Check if cloning was successful and created a valid Git repository
    if not os.path.exists(os.path.join(REPO_PATH, '.git')):
        print("\n--- GitHub Clone Failed or Invalid Repository ---")
        print("Please check the following:")
        print(f"1. Does the repository 'https://github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git' actually exist and is spelled correctly?")
        print(f"2. Is your 'github_token' correct, and does it have 'repo' scope permissions (especially if the repo is private)?")
        print("Git output during clone attempt:")
        for line in clone_result:
            print(line)
        raise SystemExit("Cloning repository failed or did not create a valid .git directory. Please fix the issue and re-run.")
    else:
        print(f"Repository '{GITHUB_REPO_NAME}' cloned successfully to {REPO_PATH}/")

# Create data directory if it doesn't exist within the cloned repo
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# CSV Logic
# Save dim_date
dim_date.to_csv(f'{DATA_PATH}/dim_date.csv', index=False)
print(f"DataFrame dim_date saved to {DATA_PATH}/dim_date.csv")

# Save dim_vehicle
dim_vehicle.to_csv(f'{DATA_PATH}/dim_vehicle.csv', index=False)
print(f"DataFrame dim_vehicle saved to {DATA_PATH}/dim_vehicle.csv")

# Save fact_coe
fact_coe.to_csv(f'{DATA_PATH}/fact_coe.csv', index=False)
print(f"DataFrame fact_coe saved to {DATA_PATH}/fact_coe_prices.csv")

# Change directory into your repository for Git operations
# %cd {REPO_PATH}

# Configure your Git identity (only needs to be done once per session)
# These are often global, but setting them here ensures they are set for this session
# !git config user.email "{GITHUB_EMAIL}"
# !git config user.name "{GITHUB_NAME}"

# Add, Commit, and Push the CSV file
# !git add {DATA_PATH}/*.csv
# !git commit -m "Automated update of dim_date.csv, dim_vehicle.csv, and fact_coe_prices.csv"
# !git push https://{github_token}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git

print("Changes pushed to GitHub!")

# --- Google Drive Push Logic ---
print(f"\nAttempting to push CSV files to Google Drive folder '{GOOGLE_DRIVE_FOLDER_NAME}'...")

drive_path = f'/content/drive/MyDrive/{GOOGLE_DRIVE_FOLDER_NAME}'

# Check if Google Drive is mounted, if not, attempt to mount it
if not os.path.exists('/content/drive'):
    print("Google Drive is not mounted. Attempting to mount now...")
    drive.mount('/content/drive')
    # Re-check after mounting attempt
    if not os.path.exists('/content/drive'):
        print("Error: Google Drive could not be mounted. Skipping Drive push.")
        print("Please ensure you authenticate Google Drive correctly when prompted.")
    else:
        print("Google Drive mounted successfully for Drive push.")
else:
    print("Google Drive is already mounted.")

# Proceed with copying if Drive is mounted
if os.path.exists('/content/drive'):
    # Create the folder in Google Drive if it doesn't exist
    if not os.path.exists(drive_path):
        os.makedirs(drive_path)
        print(f"Created Google Drive folder: {drive_path}")

    # List of CSV files to copy
    csv_files_to_copy = ['dim_date.csv', 'dim_vehicle.csv', 'fact_coe_prices.csv']

    for csv_file_name in csv_files_to_copy:
        local_csv_path = os.path.join(DATA_PATH, csv_file_name)
        drive_destination_path = os.path.join(drive_path, csv_file_name)

        if os.path.exists(local_csv_path):
            try:
                # shutil.copy overwrites by default if destination exists
                shutil.copy(local_csv_path, drive_destination_path)
                print(f"Successfully copied {csv_file_name} to Google Drive: {drive_destination_path} (Overwritten if existed)")
            except Exception as e:
                print(f"Error copying {csv_file_name} to Google Drive: {e}")
        else:
            print(f"Warning: Local CSV file not found: {local_csv_path}")

print("Google Drive push process completed.")
# Out:
# /content
# Repository 'coe-prices' already exists. Pulling latest changes...
# /content/coe-prices
# From https://github.com/kerlyn-ong/coe-prices
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
# /content
# DataFrame dim_date saved to /content/coe-prices/data/dim_date.csv
# DataFrame dim_vehicle saved to /content/coe-prices/data/dim_vehicle.csv
# DataFrame fact_coe saved to /content/coe-prices/data/fact_coe_prices.csv
# /content/coe-prices
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Everything up-to-date
# Changes pushed to GitHub!
#
# Attempting to push CSV files to Google Drive folder 'Projects'...
# Google Drive is already mounted.
# Successfully copied dim_date.csv to Google Drive: /content/drive/MyDrive/Projects/dim_date.csv (Overwritten if existed)
# ...

# %%
# # --- Excel Export Logic ---]
# XLSX_FILE_NAME = "coe_dataset.xlsx"
# excel_path = f'{DATA_PATH}/{XLSX_FILE_NAME}'

# # Create a Pandas Excel writer using XlsxWriter as the engine.
# # This allows writing multiple DataFrames to different sheets in one file.
# with pd.ExcelWriter(excel_path, engine='xlsxwriter') as writer:
#     # Write each DataFrame to a different sheet
#     dim_date.to_excel(writer, sheet_name='dim_date', index=False)
#     print(f"DataFrame dim_date written to sheet 'dim_date' in {XLSX_FILE_NAME}")

#     dim_vehicle.to_excel(writer, sheet_name='dim_vehicle', index=False)
#     print(f"DataFrame dim_vehicle written to sheet 'dim_vehicle' in {XLSX_FILE_NAME}")

#     fact_coe.to_excel(writer, sheet_name='fact_coe', index=False)
#     print(f"DataFrame fact_coe written to sheet 'fact_coe_prices' in {XLSX_FILE_NAME}")

# print(f"All DataFrames exported to {XLSX_FILE_NAME} successfully!")

# # Change directory into your repository for Git operations
# %cd {REPO_PATH}

# # Configure your Git identity (only needs to be done once per session)
# # These are often global, but setting them here ensures they are set for this session
# !git config user.email "{GITHUB_EMAIL}"
# !git config user.name "{GITHUB_NAME}"

# # Add, Commit, and Push the XLSX file (and remove old CSVs if they were previously created)
# !git add {DATA_PATH}/*.xlsx
# !git add -u # Add/remove any files that have been modified/deleted in the repo
# !git commit -m "Automated update: Exported data to {XLSX_FILE_NAME} (dim_date, dim_vehicle, fact_coe)"
# !git push https://{github_token}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git

# print("Changes pushed to GitHub!")
